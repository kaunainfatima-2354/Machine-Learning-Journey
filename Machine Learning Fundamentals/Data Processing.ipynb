# %% [markdown]
# # Data Cleaning

# %%
# import pandas as pd
# from sklearn.preprocessing import LabelEncoder

# %%
# data = {
#     'Name': ['Kaunain', 'Yuki', 'Yami', 'Snow'],
#     'Age' : [25, None, 14, None],
#     'Salary': [50000, 3294, None, 6000]
# }

# df =  pd.DataFrame(data)
# print("Original data")
# print(df)
# df['Age'].fillna(df['Age'].mean(), inplace=True)
# df['Salary'].fillna(df['Salary'].mode(), inplace=True)
# print(df)

# %% [markdown]
# # Data Encoding

# %%
# df = pd.read_csv('/content/sample_data.csv')
# df_label = df.copy()

# le =  LabelEncoder()
# df_label['Gender_Encoded'] = le.fit_transform(df_label['Gender'])
# df_label['Passed_Encoded'] = le.fit_transform(df_label['Passed'])

# %%
# print(df_label[['Gender', 'Gender_Encoded', 'Passed', 'Passed_Encoded']])

# %%
# df_encoded = pd.get_dummies(df, columns=['City'])
# df_encoded[['City_Bengaluru', 'City_Ahmedabad', 'City_Chandigarh', 'City_Chennai', 'City_Coimbatore', 'City_Delhi', 'City_Goa', 'City_Hyderabad', 'City_Indore', 'City_Jaipur', 'City_Kolkata', 'City_Lucknow', 'City_Mumbai', 'City_Nagpur', 'City_Pune', 'City_Surat']] = df_encoded[['City_Bengaluru', 'City_Ahmedabad', 'City_Chandigarh', 'City_Chennai', 'City_Coimbatore', 'City_Delhi', 'City_Goa', 'City_Hyderabad', 'City_Indore', 'City_Jaipur', 'City_Kolkata', 'City_Lucknow', 'City_Mumbai', 'City_Nagpur', 'City_Pune', 'City_Surat']].astype(int)
# print(df_encoded)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
# data = {
#     'Age': [22, 35, 29, 41, 26, 33, 19, 48],
#     'Time_Spent': [15, 32, 28, 12, 45, 38, 10, 20],
#     'Purchased': ['No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'No']
# }

# df = pd.DataFrame(data)

#Standard Scalar

# standard_scalar = StandardScaler()
# standard_scaled = standard_scalar.fit_transform(df)

# print(pd.DataFrame(standard_scaled, columns=['StudyHours', 'TestScore']))

# mimmax_scalar = MinMaxScaler()
# minmax_scaled = mimmax_scalar.fit_transform(df)

# print(pd.DataFrame(minmax_scaled, columns=['StudyHours', 'TestScore']))

# X = df[['Age', 'Time_Spent']]
# y = df['Purchased']

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

# print("🧠 X_train:")
# print(X_train.join(y_train))
# print("\n📎 X_test:")
# print(X_test.join(y_test))

# %%
# Out:
# Enter how many hours you studied: 9
# Based on your 9.0 hours you studied, you can scare around [80.]
