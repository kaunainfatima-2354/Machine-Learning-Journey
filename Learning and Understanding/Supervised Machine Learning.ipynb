# %% [markdown]
# # Regression

# %%
# from sklearn.linear_model import LinearRegression
# model = LinearRegression()
# X = [[1], [2], [3], [4], [5]]
# y = [10, 17, 28, 30, 48]
# model.fit(X, y)
# hours = float(input("Enter how many hours you studied: "))
# predicted_marks = model.predict([[hours]])

# if predicted_marks < 25:
#   result= "Fail"
# elif predicted_marks >= 25:
#   result= "Pass"

# print(f"Based on your {hours} hours you studied, you can score around {predicted_marks}, from which you will {result}")

# %% [markdown]
# # Classification

# %%
# from sklearn.linear_model import LogisticRegression

# X = [[1], [2], [3], [4], [5]]
# y = [0, 0, 1, 1, 1]

# model = LogisticRegression()
# model.fit(X, y)
# hours = float(input("Enter how many hours you studied: "))
# result = model.predict([[hours]])[0]

# if result == 1:
#   print("You passed")
# else:
#   print("You failed")

# %% [markdown]
# # KNN

# %%
# from sklearn.neighbors import KNeighborsClassifier
# X = [
#     [180,7],
#     [200, 7.5],
#     [250, 8],
#     [300, 8.5],
#     [350, 9],
#     [400, 9.5]
# ]

# y = [0, 0, 0, 1, 1, 1]

# model = KNeighborsClassifier(n_neighbors=3)
# model.fit(X, y)

# weight = float(input("Enter the weight in garms: "))
# size = float(input("Enter the size in cm: "))

# prediction = model.predict([[weight, size]])[0]

# if prediction == 0:
#   print("This is likely an apple")
# else:
#   print("This is likely an orange")
# Out:
# Enter the weight in garms: 680
# Enter the size in cm: 8
# This is likely an orange

# %% [markdown]
# # Decision Trees

# %%
# from sklearn.tree import DecisionTreeClassifier
# X = [
#     [7, 2],
#     [8, 3],
#     [9, 8],
#     [10, 9]
# ]

# y = [0, 0, 1, 1]+

# model = DecisionTreeClassifier()
# model.fit(X, y)

# size = float(input("Enter the size in cm: "))
# shade = float(input("Enter the color shade from 1-10: "))

# result = model.predict([[size, shade]])[0]

# if result == 0:
#   print("Its an apple")
# else:
#   print("its an orange")
